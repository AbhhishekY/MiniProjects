# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread("/content/iiita1.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,100,200)     
cv2.imwrite('//content/sample_data/iiita1_canny_mit20129033.jpg',edges) 
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=4032x3024 at 0x7F85BAACF588>
